# %% [markdown]
# <a href="https://colab.research.google.com/github/YonggunJung/AI_Poly/blob/main/01_%EC%BD%94%EB%9E%A9_%EC%82%AC%EC%9A%A9%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
scond_in_a_day = 24*60*60
scond_in_a_day
# Out:
# 86400

# %% [markdown]
# # 특정 셀에서 정의한 변수를 나중에 다른 셀에서 사용 가능

# %%
scond_in_a_week = scond_in_a_day * 7
scond_in_a_week
# Out:
# 604800

# %% [markdown]
# ## 패키지 불러오기
#
# Colab를 통해 인기 있는 Python 라이브러리를 최대한 활용하여 데이터를 분석하고 시각화 가능

# %%
import numpy as np
# import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %% [markdown]
# ## 그래프 그리기
#
# numpy를 사용하여 임의의 데이터를 생성하고 matplotlib로 이를 시각화

# %%
# 넘파이 아래 랜덤에서 인트로(-100에서 100까지 50개) 뽑는다는 말
data = np.random.randint(-100, 100, 100)
data
# Out:
# array([  -6,   77,    3,  -67,   29,  -85,  -89,   32,  -28,    0,   94,
#          14,   54,  -45,  -16,   69,   99,   90,  -71,  -51,   34,  -32,
#         -25,   85,   42,  -34,   -1,   98,   35,   21,   37,   50,   58,
#          83,   57,   78,   61,   95,   97,  -85,   17,  -31,  -80,   50,
#         -81,  -11,   65,   -3,   49,  -46,   75,   40,  -84,   17,  -81,
#           2,  -76,   87,   24,  -51,  -19,  -84,   21,  -64,  -32,   29,
#         -27,   41,   34,    9,   85, -100,  -96,  -72,  -38,  -35,   -6,
#          76,   53,   84,    4,   39,  -70,   68,  -22,   66,  -53,  -47,
#          69,   -9,   28,    6,  -40,   76,   31,  -35,  -59,  -53,   87,
#          34])

# %%
# cumsum() : 은 누적 합
plt.plot(data.cumsum())
plt.show()

# %% [markdown]
# ## 셀(cell)
# Colab은 셀 단위로 이루어짐. 각각의 셀은 코드를포함

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# # 기본 텍스트 **굵은 텍스트** *이탤릭체 텍스트*

# %% [markdown]
# # 코드셀

# %%
print("A")
# Out:
# A

# %%
# !ls
# Out:
# sample_data

# %%
! pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.9.3
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albumentations                   1.3.1
# altair                           4.2.2
# annotated-types                  0.6.0
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.5.0
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.0
# attrs                            23.2.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.14.0
# ...

# %%
! pip install pandas_datareader

# %% [markdown]
# # 데이터 프레임 출력
#
# 야후 삼성 전자 주식 데이터

# %%
import datetime as dt
import yfinance as yf

company = '005930.KS'

start = dt.datetime(2023, 1, 1)
end = dt.datetime(2023, 3, 1)

df = yf.download(company, start, end)

df.tail(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2023-02-15  63900.0  63900.0  62000.0  62200.0  60926.214844     58370
# 2023-02-16  62500.0  63700.0  62400.0  63700.0  62395.496094     41448
# 2023-02-17  62900.0  63300.0  62400.0  62600.0  61318.023438     28613
# 2023-02-20  62900.0  63000.0  61800.0  62700.0  61415.972656     29846
# 2023-02-21  62700.0  62800.0  62000.0  62100.0  60828.265625     60971
# 2023-02-22  61500.0  61800.0  61000.0  61100.0  59848.738281     39178
# 2023-02-23  61700.0  62500.0  61500.0  62000.0  60730.308594     37145
# 2023-02-24  62300.0  62600.0  61300.0  61300.0  60044.640625     50792
# 2023-02-27  60800.0  60800.0  60200.0  60500.0  59261.027344  11155697
# 2023-02-28  60800.0  61400.0  60500.0  60600.0  59358.980469  13715861

# %%
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>
